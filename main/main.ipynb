# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv("IRIS.csv")

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['species'] = le.fit_transform(df['species'])

# %%
X = df.drop(columns="species")
y = df.species

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1,random_state = 20)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbr = GradientBoostingClassifier(n_estimators = 1)
gbr.fit(X_train, y_train)
gbr.score(X_test, y_test)
# Out:
# 0.9333333333333333

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators' : [10, 20, 30, 40, 50],
    'learning_rate' : [1, 0.1, 0.01, 0.001, 0.0001],
    'max_depth' : [3, 5, 9, 20]  
}

gbr2 = GridSearchCV(gbr, param_grid, cv = 5, return_train_score=False)
gbr2.fit(X, y)
df2 = pd.DataFrame(gbr2.cv_results_)
df2
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.014694      0.006091         0.001180        0.000288
# 1        0.014370      0.001436         0.000642        0.000022
# 2        0.018595      0.001875         0.000627        0.000021
# 3        0.022128      0.001972         0.000615        0.000007
# 4        0.025558      0.001962         0.000617        0.000007
# ..            ...           ...              ...             ...
# 95       0.008047      0.000302         0.000586        0.000003
# 96       0.014850      0.000482         0.000600        0.000005
# 97       0.022595      0.000865         0.000611        0.000001
# 98       0.029469      0.001151         0.000622        0.000005
# 99       0.036443      0.001468         0.000630        0.000005
#
#     param_learning_rate  param_max_depth  param_n_estimators  \
# 0                1.0000                3                  10
# ...

# %%
df2[
['param_n_estimators', 'param_learning_rate', 'param_max_depth','mean_test_score','rank_test_score']
].sort_values(by='rank_test_score'
).head(10)
# Out:
#     param_n_estimators  param_learning_rate  param_max_depth  mean_test_score  \
# 99                  50               0.0001               20         0.966667
# 77                  30               0.0010               20         0.966667
# 76                  20               0.0010               20         0.966667
# 75                  10               0.0010               20         0.966667
# 25                  10               0.1000                5         0.966667
# 73                  40               0.0010                9         0.966667
# 72                  30               0.0010                9         0.966667
# 71                  20               0.0010                9         0.966667
# 30                  10               0.1000                9         0.966667
# 70                  10               0.0010                9         0.966667
#
#     rank_test_score
# 99                1
# 77                1
# 76                1
# 75                1
# ...
