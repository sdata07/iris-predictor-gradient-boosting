# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv("IRIS.csv")

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['species'] = le.fit_transform(df['species'])

# %%
X = df.drop(columns="species")
y = df.species

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1,random_state = 20)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbr = GradientBoostingClassifier(n_estimators = 1)
gbr.fit(X_train, y_train)
gbr.score(X_test, y_test)
# Out:
# 0.9333333333333333

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators' : [10, 20, 30, 40, 50],
    'learning_rate' : [1, 0.1, 0.01, 0.001, 0.0001],
    'max_depth' : [3, 5, 9, 20]  
}

gbr2 = GridSearchCV(gbr, param_grid, cv = 5, return_train_score=False)
gbr2.fit(X, y)
df2 = pd.DataFrame(gbr2.cv_results_)
df2
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.008141      0.000528         0.000718        0.000077
# 1        0.014202      0.001263         0.000623        0.000002
# 2        0.019167      0.002006         0.000640        0.000012
# 3        0.022717      0.001998         0.000633        0.000007
# 4        0.025956      0.002012         0.000643        0.000011
# ..            ...           ...              ...             ...
# 95       0.008195      0.000298         0.000599        0.000004
# 96       0.015100      0.000513         0.000611        0.000005
# 97       0.022863      0.000902         0.000627        0.000004
# 98       0.030075      0.001184         0.000634        0.000003
# 99       0.037027      0.001391         0.000646        0.000003
#
#     param_learning_rate  param_max_depth  param_n_estimators  \
# 0                1.0000                3                  10
# 1                1.0000                3                  20
# 2                1.0000                3                  30
# 3                1.0000                3                  40
# 4                1.0000                3                  50
# ..                  ...              ...                 ...
# 95               0.0001               20                  10
# 96               0.0001               20                  20
# 97               0.0001               20                  30
# 98               0.0001               20                  40
# 99               0.0001               20                  50
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 1, 'max_depth': 3, 'n_estima...           0.966667
# 1   {'learning_rate': 1, 'max_depth': 3, 'n_estima...           0.966667
# 2   {'learning_rate': 1, 'max_depth': 3, 'n_estima...           0.966667
# 3   {'learning_rate': 1, 'max_depth': 3, 'n_estima...           0.966667
# 4   {'learning_rate': 1, 'max_depth': 3, 'n_estima...           0.966667
# ..                                                ...                ...
# 95  {'learning_rate': 0.0001, 'max_depth': 20, 'n_...           0.966667
# 96  {'learning_rate': 0.0001, 'max_depth': 20, 'n_...           0.966667
# 97  {'learning_rate': 0.0001, 'max_depth': 20, 'n_...           0.966667
# 98  {'learning_rate': 0.0001, 'max_depth': 20, 'n_...           0.966667
# 99  {'learning_rate': 0.0001, 'max_depth': 20, 'n_...           0.966667
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.966667                0.9           0.966667
# 1            0.966667                0.9           0.966667
# 2            0.966667                0.9           0.933333
# 3            0.966667                0.9           0.933333
# 4            0.966667                0.9           0.966667
# ..                ...                ...                ...
# 95           0.966667                0.9           1.000000
# 96           0.966667                0.9           1.000000
# 97           0.966667                0.9           1.000000
# 98           0.966667                0.9           1.000000
# 99           0.966667                0.9           1.000000
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 1.0         0.960000        0.032660               31
# 1                 1.0         0.960000        0.032660               31
# 2                 1.0         0.953333        0.033993               93
# 3                 1.0         0.953333        0.033993               93
# 4                 1.0         0.960000        0.032660               31
# ..                ...              ...             ...              ...
# 95                1.0         0.966667        0.036515                1
# 96                1.0         0.966667        0.036515                1
# 97                1.0         0.966667        0.036515                1
# 98                1.0         0.966667        0.036515                1
# 99                1.0         0.966667        0.036515                1
#
# [100 rows x 16 columns]

# %%
df2[['param_C', 'param_kernel', 'mean_test_score']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[153], line 1
# ----> 1 df2[['param_C', 'param_kernel', 'mean_test_score']]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['param_C', 'param_kernel'] not in index"
